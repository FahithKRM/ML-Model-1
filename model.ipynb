# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# load dataset
data = {
    'Mid_Semester_Marks': [70, 80, 65, 90, 75, 85, 60, 95, 55, 88, 78, 84, 62, 91, 73, 89, 64, 93, 59, 86,
                  71, 82, 67, 92, 77, 87, 66, 94, 61, 83, 72, 81, 63, 90, 74, 85, 69, 88, 68, 91,
                  79, 86, 65, 93, 70, 89, 61, 95, 60, 84, 73, 87, 76, 83, 67, 92, 69, 85, 63, 91,
                  80, 87, 66, 88, 77, 82, 64, 94, 78, 89, 71, 92, 72, 90, 74, 88, 75, 86, 68, 91,
                  81, 84, 62, 93, 76, 83, 59, 94, 77, 90, 67, 89, 70, 95, 65, 84, 78, 82, 64, 92],

    'Attendance': [90, 85, 80, 95, 70, 88, 60, 98, 50, 90, 85, 78, 64, 89, 77, 84, 68, 93, 55, 91,
                   72, 83, 66, 88, 69, 92, 62, 97, 58, 86, 73, 81, 67, 94, 71, 87, 59, 93, 65, 90,
                   74, 88, 61, 92, 77, 85, 68, 91, 62, 87, 79, 89, 60, 94, 73, 86, 69, 82, 66, 90,
                   81, 85, 63, 91, 70, 93, 57, 88, 77, 86, 64, 95, 72, 89, 66, 92, 71, 90, 68, 88,
                   80, 84, 61, 96, 75, 87, 55, 94, 78, 91, 64, 89, 72, 98, 60, 90, 76, 82, 65, 93],

    'End_Semester_Marks': [75, 82, 68, 92, 78, 84, 58, 93, 53, 87, 79, 86, 65, 90, 74, 88, 69, 94, 56, 93,
                           60, 85, 73, 89, 66, 91, 76, 87, 63, 95, 61, 83, 72, 88, 64, 90, 75, 84, 68, 92,
                           68, 92, 70, 89, 81, 87, 65, 93, 78, 88, 62, 94, 67, 85, 79, 89, 74, 86, 61, 90,
                           71, 92, 77, 83, 65, 90, 73, 87, 69, 91, 76, 84, 66, 93, 75, 88, 70, 89, 68, 92,
                           80, 85, 63, 94, 78, 86, 59, 92, 77, 90, 65, 89, 68, 95, 62, 87, 74, 83, 67, 91]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    Mid_Semester_Marks  Attendance  End_Semester_Marks
# 0                  70          90                  75
# 1                  80          85                  82
# 2                  65          80                  68
# 3                  90          95                  92
# 4                  75          70                  78

# %%
# data cleaning
df.isna().sum()
# Out:
# Mid_Semester_Marks    0
# Attendance            0
# End_Semester_Marks    0
# dtype: int64

# %%
# data preprocessing
X = df[['Mid_Semester_Marks', 'Attendance']]
y = df['End_Semester_Marks']

# %%
# data spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 42)

# %%
# create model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# calculate the prediction
y_pred = model.predict(X_test)

# %%
# save the trained model to a file
import pickle

with open('linear_regression_model.pkl', 'wb') as file : 
    pickle.dump(model, file)

# %%
# calculate the matrix
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error : ", mse)
print("R_2 Score : ", r2)
# Out:
# Mean Squared Error :  21.827773670871622
# R_2 Score :  0.7915478632109714

# %%
# visualized
plt.scatter(y_test, y_pred)
plt.xlabel("Acutal Marks")
plt.ylabel("Predict Marks")
plt.title("Acutal vs Predict")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color = 'red')
plt.show()
